# %% [markdown]
# # Json API Assignment
#     Student : Chotipong Saengkhunthod 60070133
# ***

# %% [markdown]
# ## Import json api data

# %%
import json
import requests
respond = requests.get("https://chronicdata.cdc.gov/views/mfvi-hkb9/rows.json")
data = json.loads(respond.text)

# %% [markdown]
# ## Show json data

# %% [markdown]
# ## Parsing Json to CSV

# %%
column = [i["name"] for i in data["meta"]["view"]["columns"]]
import pandas as pd

# %%
df = pd.DataFrame(columns=column)
df
# Out:
# Empty DataFrame
# Columns: [sid, id, position, created_at, created_meta, updated_at, updated_meta, meta, Year, LocationAbbr, LocationDesc, GeographicLevel, DataSource, Class, Topic, Data_Value, Data_Value_Unit, Data_Value_Type, Data_Value_Footnote_Symbol, Data_Value_Footnote, StratificationCategory1, Stratification1, StratificationCategory2, Stratification2, TopicID, LocationID, Y_lat, X_lon, Georeference Column, States, Counties]
# Index: []
#
# [0 rows x 31 columns]

# %%
lst = []
for i in range(0,len(column)):
    for x in data["data"]:
        lst.append(x[i])
    df[column[i]] = lst
    lst = []

# %% [markdown]
# ## Data Selection

# %%
df = df[df["GeographicLevel"]=="County"].iloc[:,8:]
df = df[df["Stratification1"]=="Overall"]
from IPython.display import HTML
HTML(df.head(50).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>LocationAbbr</th>
#       <th>LocationDesc</th>
#       <th>GeographicLevel</th>
#       <th>DataSource</th>
#       <th>Class</th>
#       <th>Topic</th>
#       <th>Data_Value</th>
#       <th>Data_Value_Unit</th>
#       <th>Data_Value_Type</th>
#       <th>Data_Value_Footnote_Symbol</th>
#       <th>Data_Value_Footnote</th>
#       <th>StratificationCategory1</th>
#       <th>Stratification1</th>
#       <th>StratificationCategory2</th>
#       <th>Stratification2</th>
#       <th>TopicID</th>
#       <th>LocationID</th>
#       <th>Y_lat</th>
#       <th>X_lon</th>
#       <th>Georeference Column</th>
#       <th>States</th>
#       <th>Counties</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>24</th>
#       <td>2016</td>
#       <td>AL</td>
#       <td>Limestone County</td>
#       <td>County</td>
#       <td>NVSS</td>
# ...

# %%
df_sample = pd.read_csv("laucnty16.csv")
df_sample = df_sample.iloc[:,1:4]
df["County Name/State Abbreviation"] = df["LocationDesc"]+","+" "+df["LocationAbbr"]

# %%
df_merge_col = pd.merge(df, df_sample, on='County Name/State Abbreviation')

# %%
df_merge_col["State FIPS Code"] = [str(i).zfill(2) for i in df_merge_col["State FIPS Code"]]
df_merge_col["County FIPS Code"] = [str(i).zfill(3) for i in df_merge_col["County FIPS Code"]]

# %%
df_merge_col["fibs"] = df_merge_col["State FIPS Code"]+df_merge_col["County FIPS Code"]

# %%
df_merge_col["Data_Value"] = df_merge_col["Data_Value"].astype(float).fillna(0)

# %%
df_State = pd.read_csv("abbr-name.csv")
df_merge_col = pd.merge(df_merge_col, df_State, on='LocationAbbr')
df_merge_col2 = df_merge_col[df_merge_col["Stratification2"]=="Overall"]

# %%
import plotly
plotly.io.orca.config.save()
from IPython.display import SVG, display

# %%
import plotly.figure_factory as ff

import numpy as np
import pandas as pd

colorscale = ["#f7fbff","#ebf3fb","#deebf7","#c6dbef","#b3d2e9","#9ecae1","#6baed6","#57a0ce","#4292c6","#2171b5","#1361a9",
              "#08519c","#08306b"]
endpts = list(np.linspace(min(df_merge_col2["Data_Value"]), max(df_merge_col2["Data_Value"]), len(colorscale) - 1))
fips = df_merge_col2["fibs"].tolist()
values = df_merge_col2["Data_Value"].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=False,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='Hearth disease %',
    legend_title='Per 100k populations'
)

fig.layout.template = None
img_bytes = pio.to_image(fig, format="svg")
display(SVG(img_bytes))

# %%
top_5 = df_merge_col2.groupby(["LocationAbbr"]).sum().sort_values(['Data_Value'], ascending=0).head(5)
top_5 = pd.merge(top_5,df_State, on='LocationAbbr')
top_5
# Out:
#   LocationAbbr  Data_Value State_name
# 0           TX     96590.4      Texas
# 1           GA     62036.3    Georgia
# 2           KY     51382.2   Kentucky
# 3           MO     45885.3   Missouri
# 4           TN     41525.5  Tennessee

# %%
bar = top_5
bar.index = bar["State_name"]
bar.plot.bar()

# %%
import plotly.io as pio
from IPython.display import SVG, display
for i in list(top_5["State_name"]):
    plotz = df_merge_col2[df_merge_col2["State_name"]==i]

    values = plotz['Data_Value'].tolist()
    fips = plotz['fibs'].tolist()

    endpts = list(np.mgrid[min(values):max(values):6j])

    colorscale = ["#030512","#1d1d3b","#323268","#3d4b94","#3e6ab0",
              "#4989bc","#60a7c7","#85c5d3","#b7e0e4","#eafcfd"]
    fig = ff.create_choropleth(
        fips=fips, values=values, scope=[i], show_state_data=True,
        colorscale=colorscale, binning_endpoints=endpts, round_legend_values=True,
        plot_bgcolor='rgb(229,229,229)',
        paper_bgcolor='rgb(229,229,229)',
        legend_title='Hearth Disease in '+i,
        county_outline={'color': 'rgb(255,255,255)', 'width': 0.5},
        exponent_format=True,
    )
    fig.layout.template = None
    img_bytes = pio.to_image(fig, format="svg")
    display(SVG(img_bytes))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
